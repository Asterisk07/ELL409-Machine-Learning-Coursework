# %%
#real time plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import time
# Scatter plot with x and y
plt.scatter([], [], cmap='hot')
marker_color = 'blue'
plt.xlim(0, 10)
for i in range(10):
    # inr=int(input("enter number"))
    # if (i==0):
    #     print("ended")
    #     break
    plt.scatter([i], [i])
    # plt.scatter([i], [i], marker='.',ls='none', ms=10,color=marker_color)
    # plt.show()
    plt.draw()
    # plt.show()
    time.sleep(1)
    display
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_20388\2237016818.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter([], [], cmap='hot')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 19
#      17 plt.draw()
#      18 # plt.show()
# ---> 19 time.sleep(1)
#      20 display
#
# KeyboardInterrupt:
